# %%
# %sql
DROP TABLE IF EXISTS dev.mohit_gangwani.content_with_null_cognet_2025_10_29_22_production;
CREATE TABLE dev.mohit_gangwani.content_with_null_cognet_2025_10_29_22_production (
    tvid string, hash string, zipcode string, dma string, episode_id string, show_title string, air_date string, channel_callsign string, mt_start integer, ts_start timestamp, ts_end timestamp, channel_affiliate string, live string, ip string, input_category string, input_device string, app_service string, content_type string, reported_input_source string
    );
INSERT INTO dev.mohit_gangwani.content_with_null_cognet_2025_10_29_22_production (
    tvid, 
    hash, 
    zipcode, 
    dma, 
    episode_id, 
    show_title, 
    air_date, 
    channel_callsign, 
    mt_start, 
    ts_start, 
    ts_end, 
    channel_affiliate, 
    live, 
    ip, 
    input_category, 
    input_device, 
    app_service,
    content_type,
    reported_input_source
)
SELECT /*+ BROADCAST(wfd_check) 
      SHUFFLE_HASH(hashed_table)   
         */ DISTINCT
    mt.tvid as tvid, 
    '' as hash, 
    mt.zipcode as zipcode, 
    mt.dma as dma, 
    CASE WHEN mt.vizio_epg_not_null THEN CASE WHEN 'TIVO' = 'TMS' THEN mt.tms_episode_id ELSE NULL END 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen'  AND mt.nielsen_exclusive THEN NULL 
       WHEN False = FALSE AND mt.vod_station = TRUE THEN NULL 
       WHEN 'TIVO' = 'TMS'  THEN mt.tms_episode_id 
       WHEN 'TIVO' = 'TIVO' THEN mt.tivo_episode_id 
    END as episode_id, 
    CASE WHEN mt.vizio_epg_not_null THEN CASE WHEN 'TIVO' = 'TMS' THEN COALESCE(mt.tms_title, mt.tivo_title) 
           ELSE COALESCE(mt.tivo_title, mt.tms_title) END 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen'  AND mt.nielsen_exclusive THEN NULL 
       WHEN False = FALSE AND mt.vod_station = TRUE THEN NULL 
       WHEN 'cognet' = 'nielsen' THEN mt.tms_title 
       WHEN 'TIVO' = 'TMS'  THEN COALESCE(mt.tms_title, mt.tivo_title) 
       WHEN 'TIVO' = 'TIVO' THEN COALESCE(mt.tivo_title, mt.tms_title) 
    END as show_title, 
    CASE WHEN mt.vizio_epg_not_null THEN CASE WHEN 'TIVO' = 'TMS' THEN COALESCE(mt.tms_airdate, mt.tivo_airdate) 
           ELSE COALESCE(mt.tivo_airdate, mt.tms_airdate) END 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen'  AND mt.nielsen_exclusive THEN NULL 
       WHEN False = FALSE AND mt.vod_station = TRUE THEN NULL 
       WHEN 'cognet' = 'nielsen' THEN mt.tms_airdate 
       WHEN 'TIVO' = 'TMS'  THEN COALESCE(mt.tms_airdate, mt.tivo_airdate) 
       WHEN 'TIVO' = 'TIVO' THEN COALESCE(mt.tivo_airdate, mt.tms_airdate) 
    END as air_date, 
    CASE WHEN mt.vizio_epg_not_null THEN CASE WHEN 'TIVO' = 'TMS' THEN COALESCE(mt.tms_channel_callsign, mt.tivo_channel_callsign) 
           ELSE COALESCE(mt.tivo_channel_callsign, mt.tms_channel_callsign) END 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen' AND mt.nielsen_exclusive THEN NULL 
       WHEN False = FALSE AND mt.vod_station = TRUE THEN NULL 
       WHEN 'cognet' = 'nielsen'   THEN mt.tms_channel_callsign 
       WHEN 'TIVO' = 'TMS'  THEN COALESCE(mt.tms_channel_callsign, mt.tivo_channel_callsign) 
       WHEN 'TIVO' = 'TIVO' THEN COALESCE(mt.tivo_channel_callsign, mt.tms_channel_callsign) 
    END as channel_callsign, 
    CASE WHEN mt.vizio_epg_not_null THEN mt.mt_start 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen'  AND mt.nielsen_exclusive   THEN NULL 
       WHEN False = FALSE          AND mt.vod_station = TRUE  THEN NULL 
       WHEN 'cognet' = 'nielsen' AND mt.tms_airdate IS NULL THEN NULL 
       ELSE mt.mt_start 
    END as mt_start, 
    mt.session_start as ts_start, 
    mt.session_end as ts_end, 
    CASE WHEN mt.vizio_epg_not_null THEN CASE WHEN 'TIVO' = 'TMS' THEN COALESCE(mt.tms_channel_affiliate, mt.tivo_channel_affiliate) 
           ELSE COALESCE(mt.tivo_channel_affiliate, mt.tms_channel_affiliate) END 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen' AND mt.nielsen_exclusive THEN NULL 
       WHEN False = FALSE AND mt.vod_station = TRUE THEN NULL 
       WHEN 'cognet' = 'nielsen' THEN mt.tms_channel_affiliate 
       WHEN 'TIVO' = 'TMS'  THEN COALESCE(mt.tms_channel_affiliate, mt.tivo_channel_affiliate) 
       WHEN 'TIVO' = 'TIVO' THEN COALESCE(mt.tivo_channel_affiliate, mt.tms_channel_affiliate) 
    END as channel_affiliate, 
    CASE WHEN mt.vizio_epg_not_null THEN 't' 
       WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
       WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
       WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
       WHEN 'cognet' != 'nielsen' AND mt.nielsen_exclusive THEN NULL 
       WHEN False = FALSE AND mt.vod_station = TRUE THEN NULL 
       WHEN 'cognet' = 'nielsen'  AND mt.tms_airdate IS NULL THEN NULL 
       WHEN 'cognet' != 'nielsen' AND COALESCE(mt.tivo_airdate, mt.tms_airdate) IS NULL THEN NULL 
       ELSE mt.is_live
    END as live,
    mt.ip_address as ip,
    mt.input_category as input_category,
    mt.input_device as input_device,
    CASE WHEN mt.vizio_epg_not_null = False 
       THEN CASE WHEN mt.appb_clients <=> '|ALL|' AND '' <=> NVL(mt.app_service, '98989898') THEN mt.app_service 
              WHEN mt.appb_clients IS NOT NULL AND mt.appb_clients != '||' AND mt.appb_clients NOT LIKE '%|cognet|%' THEN 'OBFUSCATED' 
              WHEN mt.appb_clients <=> '|ALL|' THEN 'OBFUSCATED' 
              ELSE mt.app_service END
       ELSE mt.app_service
    END as app_service,
    CASE WHEN mt.vizio_epg_not_null THEN mt.content_type 
         WHEN mt.acrb_clients NOT IN ('||', '|ALL|') AND mt.acrb_clients NOT LIKE '%|cognet|%' THEN NULL 
         WHEN mt.acrb_clients <=> '|ALL|' AND NOT('' <=> NVL(mt.app_service, '98989898')) THEN NULL 
         WHEN mt.client_id_not_null != '||' AND mt.client_id_not_null NOT LIKE '%|cognet|%' THEN NULL 
         WHEN 'cognet' != 'nielsen' AND mt.nielsen_exclusive THEN NULL 
         WHEN mt.vod_station = TRUE THEN NULL
         ELSE mt.content_type
    END as content_type,
    mt.reported_input_source
    FROM 
( 
SELECT viz.* FROM prod.detection.viewing_content_golden AS viz
    WHERE 
        viz.session_start >= '2025-10-29T22:00:00'::timestamp
        AND viz.session_start < '2025-10-29T23:00:00'::timestamp
        AND viz.session_start_hour >= DATE_TRUNC('HOUR', '2025-10-29T22:00:00'::timestamp)
        AND viz.session_start_hour <= DATE_TRUNC('HOUR', '2025-10-29T23:00:00'::timestamp)
) AS mt
    JOIN prod.detection.tv_populations AS u
        ON mt.fk_tvid = u.fk_tvid
    JOIN prod.detection.populations AS pop
        ON u.fk_population_id = pop.population_id 
        AND pop.population_name = 'opted_in';
